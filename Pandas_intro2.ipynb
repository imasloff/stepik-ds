# %%
import pandas as pd
import numpy as np

# %%
students_perfomance = pd.read_csv("https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv")

# %%
students_perfomance.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_perfomance["math score"].hist()
# Out:
# <AxesSubplot:>

# %%
students_perfomance.loc[students_perfomance.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_perfomance.loc[students_perfomance['writing score'] > students_perfomance['writing score'].mean()]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
(students_perfomance.lunch == 'free/reduced').mean()
# Out:
# 0.355

# %%
students_perfomance.groupby('lunch').aggregate({'math score':['count', 'mean', 'std'], 'reading score':['count', 'mean', 'std'], 'writing score' :['count', 'mean', 'std']})
# Out:
#              math score                       reading score             \
#                   count       mean        std         count       mean
# lunch
# free/reduced        355  58.921127  15.159956           355  64.653521
# standard            645  70.034109  13.653501           645  71.654264
#
#                         writing score
#                     std         count       mean        std
# lunch
# free/reduced  14.895339           355  63.022535  15.433823
# standard      13.830602           645  70.823256  14.339487

# %%
students_perfomance.diff
# Out:
# <bound method DataFrame.diff of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
red_lunch = students_perfomance.lunch == 'free/reduced'
stand_lunch = students_perfomance.lunch == 'standard'

# %%
students_perfomance.loc[red_lunch].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
students_perfomance.loc[stand_lunch].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-a8b64e4d8d6d> in <module>
# ----> 1 students_perfomance.query()
#
# TypeError: query() missing 1 required positional argument: 'expr'
